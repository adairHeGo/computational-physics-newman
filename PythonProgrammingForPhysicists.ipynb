# %% [markdown]
# Exercise 2.1: Another ball dropped from a tower
#
# A ball is again dropped from a tower of height $h$ with initial velocity 0. Write a program  that asks  the user  to enter the height in meters of the tower and then calculates and prints  the time the ball takes until it hits the ground, ignoring air resistance. Use your program to calculate the time for a ball dropped from a 100 m high tower.

# %% [markdown]
# Using Newton's second law:
# $$ma=-mg,$$
# we solve the differential equation integrating over $t$ and using the initial conditions $v_0=0$ and $z_0=h$. So
# $$z=-\frac{1}{2}g t^2 + h.$$
# We are asked to calculate the time it takes the ball to hit the ground, this means $z(\tau)=0$:
# $$-h=-\frac{1}{2}g\tau^2,$$
# solving for $\tau$:
# $$\tau=\sqrt{\frac{2h}{g}}$$

# %%
#We need h
h = float(input("Enter h: "))
#acceleration of gravity
g = 9.81
#We calculate t
t=(2*h/g)**(1/2)
print(t)
# Out:
# Enter h: 100
# 4.515236409857309

# %% [markdown]
# Exercise 2.2
# A satellite is to be launched into a circular orbit around the Earth so that it orbits the planet once every $T$ seconds.
# a) Show that the altitude $h$ above the Earth's surface that the satellite must have is
# $$h=\left(\frac{GMT^2}{4\pi^2}\right)^{1/3}-R,$$
# where $G=6.67\times 10^{-11}m^3kg^{-1}s^{-2}$ is Newton's gravotational constant, $M=5.97\times 10^{24}$ kg is the mass of the Earth, and $R=6371$ km is its radius.

# %% [markdown]
# We use Newton's second law:
# $$ma=G\frac{Mm}{r^2}.$$
# For a circular orbit with period $T$:
# $$a=r\omega^2=r \left(\frac{2\pi}{T}\right)=\frac{r 4pi^2}{T^2}.$$
# So,
# $$r=\left(\frac{GMT^2}{4\pi^2}\right)^{1/3},$$
# or
# $$h=\left(\frac{GMT^2}{4\pi^2}\right)^{1/3}-R.$$

# %% [markdown]
# b) Write a program that asks the user to enter the desired value of $T$ and then calculates and prints out the correct altitude in meters

# %%
#We define the constants
G = 6.67*(10**(-11))
M = 5.97*(10**(24))
R = 6371000 #in meters
pi = 3.1416
#We ask for T
T = float(input("Enter the desired value of T: "))
#We calculate h
h = ((G*M*(T**2))/(4*(pi**2)))**(1/3) - R
#Print h
print(h, "m")
# Out:
# Enter the desired value of T: 1
# -6349393.746574965 m

# %% [markdown]
# c) Use your program to calculate the altitudes of satellites that orbit the Earth once a day (so-called "geosynchronous" orbit), once every 90 minutes, and once every 45 minutes. What do you conclude from the last of these calculations?

# %%
T = 24*60*60 #1 day -> s
#We calculate h
h = ((G*M*(T**2))/(4*(pi**2)))**(1/3) - R
#Print h
print(h, "m")
# Out:
# 35855844.34638021 m

# %%
T = 90*60 #90 min -> s
#We calculate h
h = ((G*M*(T**2))/(4*(pi**2)))**(1/3) - R
#Print h
print(h, "m")
# Out:
# 279311.257829844 m

# %%
T = 45*60 #45 min -> s
#We calculate h
h = ((G*M*(T**2))/(4*(pi**2)))**(1/3) - R
#Print h
print(h, "m")
# Out:
# -2181566.4289536644 m

# %% [markdown]
# The last calculation is impossible, this means the satellite or whatever it is is inside the Earth and still orbiting.

# %% [markdown]
# d) Technically a geosynchronous satellite is one that orbits the Earth once per sidereal day, which is 23.93 hours, not 24 hours. Why is this? And how much difference will it make to the altitude of the satellite?

# %%
T = 23.93*60*60 #23.93 h -> s
#We calculate h
h = ((G*M*(T**2))/(4*(pi**2)))**(1/3) - R
#Print h
print(h, "m")
# Out:
# 35773696.62816557 m

# %%
#The difference is
print(35855844.34638021-35773696.62816557, "m")
# Out:
# 82147.71821463853 m

# %% [markdown]
# Exercise 2.3: Write a program to perform the inverse operation to that of Example 2.2. That is, ask the user for the cartesian coordinates $x,y$ of a point in two dimensional space, and calculate and print the corresponding polar coordinates, with the angle $\theta$ given in degrees.

# %% [markdown]
# We have:
# $$r^2=x^2+y^2,$$
# and
# $$\frac{y}{x}=\tan\theta.$$
# So we have the special case when $x=0 \implies \theta=\pi/2, 3\pi/2$. Of course we have to add that $\tan \theta$ is not one to one in the interval $\theta \in [0,2\pi).$ So we have:
# $$\theta=\arctan \frac{y}{x}, x> 0, y>0$$
# $$\theta=\arctan \frac{y}{x}+\pi, x< 0, y>0$$
# $$\theta=\arctan \frac{y}{x}+\pi, x> 0, y>0$$
# $$\theta=\arctan \frac{y}{x}+2\pi, x> 0, y>0$$
# $$\theta=\pi/2, x=0,y>0$$
# $$\theta=3\pi/2, x=0, y<0$$

# %%
from math import sqrt, atan, pi
#We ask for the x and y coordinates
x = float(input("Introduce the x coordinate: "))
y = float(input("Introduce the y coordinate: "))
#We calculate r
r = sqrt(x**2 + y**2)
#Now we calculate theta. So in the text we haven't seen if-statements and that kind of stuff so I will use atan
theta = atan(y/x) #with x =! 0
print(r)
print(theta*180/pi)
# Out:
# Introduce the x coordinate: 1
# Introduce the y coordinate: 2
# 2.23606797749979
# 63.43494882292201

# %% [markdown]
# Exercise 2.4: A spaceship travels from Earth in a straight line at relativistic speed $v$ to another planet $x$ light years away. Write a program to ask the user for the value of $x$ and the speed $v$ as a fraction of the speed of light $c$, then print out the time in years that the spaceship takes to reach its destination (a) in the rest frame of an observer on Earth and (b) as perceived by a passengeron board the ship. Use your program to calculate the answers for a planet 10 light years away with $v=0.99c.$

# %%
from math import sqrt
#We ask for x and v
x = float(input("Introduce the distance x in light years: "))
v = float(input("Introduce v as a fraction o light speed c: "))
#We calculate gamma
gamma = 1/sqrt(1-v**2)
print(gamma)
#We print time t (a)
print(x/v, "years")
#We print time t (b)
print(x/(v*gamma), "years")
#for 10 light years and v=0.99c
# Out:
# Introduce the distance x in light years: 10
# Introduce v as a fraction o light speed c: 0.99
# 7.088812050083354
# 10.1010101010101 years
# 1.4249228262288782 years

# %% [markdown]
# Exercise 2.5: Quantum potential step
# A well known quantum mechanics problem involves a particle of mass $m$ that encounters a one-dimensional potential step, like this: (figure in the book)
# The particle with initial kinetic energy $E$ and wavevector $k_1=\sqrt(2mE)/\hbar$ enters from the left and encounters a sudden jump in potential energy of height $V$ at position $x=0$. By solving the Schr\"{o}dinger equation, one can show thet when $E>V$ the particle may either (a) pass the step, in which case it has a lower kinetic energy $E-V$ on the other side and a correspondingly smaller wavevector of $k_2=\sqrt{2m(E-V)}/\hbar$, or (b) it may be reflected , keeping all  of its kinetic energy and an unchanged wavevector but moving in the opposite direction. The probabilities $T$ and $R$ for transmission and reflection are given by
# $$T=\frac{4k_1k_2}{(k_1+k_2)^2}, R=\left(\frac{k_1-k_2}{k_1+k_2}\right)^2.$$
# Suppose we have a particle with mass equal to the electron mass $m=9.11\times 10^{-31}$ kg and energy 10 eV encountering a potential step of height 9 eV. Write a python program to compute and print out the transmission and reflection probabilities using the formulas above.

# %%
m = 9.11*(10**(-31))
E = 10 
V = 9
hbar = 6.582*(10**(-16))
# k1 and k2
from math import sqrt
k1 = sqrt(2*m*E)/hbar
k2 = sqrt(2*m*(E-V))/hbar
#T and R
T = (4*k1*k2)/((k1+k2)**2)
R = ((k1-k2)/(k1+k2))**2
print("T=",T)
print("R=",R)
# Out:
# T= 0.7301261363877615
# R= 0.2698738636122385

# %% [markdown]
# Exercise 2.6: The orbit in space of one body around another, such as  a planet around the Sun, need not be circular. In general it takes the form of an ellipse, with the body sometimes closer in and sometimes further out. If you are given the distance $\ell_1$ of closest approach that a  planet makes to the Sun, also called its perihelion, and its linear velocity $v_1$ at perihelion, then any other property of the orbit can be calculated from these two as follows.
# a)Kepler's second law tells us that the distance $\ell_2$ and the velocity $v_2$ of the planet at its most distant point, or aphelion, satisfy $\ell_2 v_2=\ell_1 v_1$. At the same time the total energy, kinetic plus gravitational, of a planet with velocity $v$ and distance $r$ from the Sun is given by
# $$E=\frac{1}{2}mv^2 - G\frac{mM}{r},$$
# where $m$ is the planet's mass, $M=1.9891\times 10^{30}$ kg is the mass of the Sun, and $G=6.6738\times 10^{-11}m^3kg^{-1}s^{-2}$ is Newton's gravitational constant. Given that energy must be conserved, show that $v_2$ is the smaller root of the quadratic equation
#     $$v_2^2-\frac{2GM}{v_1\ell_1}v_2-\left(v_1^2 -\frac{2GM}{\ell_1}\right)=0.$$
# Once we have $v_2$ we can calculate $\ell_2$ using the relation $\ell_2=\ell_1v_2/v_2.$

# %% [markdown]
# The solution to the quadratic equation is
# $$v_2=\frac{\frac{2GM}{v_1\ell_1}\pm \sqrt{\frac{4G^2M^2}{v_1^2\ell_1^2}+4\left(v_1^2-\frac{2GM}{\ell_1}\right)}}{2}$$
# $$v_2=\frac{GM}{v_1\ell_1}\pm \sqrt{\frac{G^2M^2}{v_1^2\ell_1^2}+\left(v_1^2-\frac{2GM}{\ell_1}\right)}$$
# $$v_2=\frac{GM}{v_1\ell_1}\pm \left(\frac{GM}{v_1\ell_1}-v_1\right)$$
# then:
# $$v_2=v_1$$
# or
# $$v_2=2\frac{GM}{v_1\ell_1}-v_1$$

# %% [markdown]
# b) Given the values of $v_1,\ell_1$, and $\ell_2$, other parameters of the orbit are given by simple formulas that can be derived from Kepler's laws and the fact that the orbit is an ellipse:
# $$Semi-major~axis:a=\frac{1}{2}(\ell_1+\ell_2)$$
# $$Semi-minor~axis:b=\sqrt{\ell_1 \ell_2}$$
# $$Orbital~period: T=\frac{2\pi ab}{\ell_1 v_1}$$
# $$Orbital~eccentricity:e=\frac{\ell_2-\ell_1}{\ell_2+\ell_1}.$$
# Write a program that asks the user to enter the distance to the sun and the velocity at perihelion, then calculates and prints the quantities $\ell_2,v_2,T$ and $e$.

# %%
from math import pi, sqrt
#We define M and G
M = 1.9891*(10**30)
G = 6.6738*(10**(-11))
#We asl for ell_1 and v_1
ell_1 = float(input("Enter the distance to the sun at perihelion"))
v_1 = float(input("Enter the velocity at perihelion"))
#We calculate ell_2, v_2, T and e
v_2 = (2*(G*M)/(v_1 * ell_1)) - v_1
print("v_2:", v_2)
ell_2 = v_1*ell_1/v_2
print("ell_2:", ell_2)
a = (ell_1+ell_2)/2
b = sqrt(ell_1*ell_2)
T = (2*pi*a*b)/(ell_1*v_1)
print("T:", T)
e = (ell_2-ell_1)/(ell_2+ell_1)
print("e:", e)
# Out:
# Enter the distance to the sun at perihelion1
# Enter the velocity at perihelion1
# v_2: 2.6549711159999998e+20
# ell_2: 3.766519319074958e-21
# T: 1.9280574589033983e-10
# e: -1.0

# %% [markdown]
# c) Test your program by having it calculate the properties of the orbits of the Earth (for which $\ell_1=1.4710\times 10^{11}$ m and $v_1=3.0287\times 10^{4}$ ms$^{-1}$) and Halley's comet ($\ell_1=8.7830\times 10^{10}$ m and $v_1=5.4529\times 10^4$ ms$^{-1}$). Among other things, you should find that the orbital period of the Earth is one year and that of Halley's comet is about 76 years.

# %%
#We use the values provided by the problem for ell_1 and v_1
ell_1 = 1.4710*(10**11) 
v_1 = 3.0287*(10**4)
#We calculate ell_2, v_2, T and e
v_2 = (2*(G*M)/(v_1 * ell_1)) - v_1
print("v_2:", v_2)
ell_2 = v_1*ell_1/v_2
print("ell_2:", ell_2)
a = (ell_1+ell_2)/2
b = sqrt(ell_1*ell_2)
T = (2*pi*a*b)/(ell_1*v_1)
print("T:", T/(365*24*60*60))
e = (ell_2-ell_1)/(ell_2+ell_1)
print("e:", e)
# Out:
# v_2: 29305.3991772613
# ell_2: 152027197208.6598
# T: 1.0002238777234556
# e: 0.016471913134741688

# %%
#We asl for ell_1 and v_1
ell_1 = 8.7830*(10**10) 
v_1 = 5.4529*(10**4)
#We calculate ell_2, v_2, T and e
v_2 = (2*(G*M)/(v_1 * ell_1)) - v_1
print("v_2:", v_2)
ell_2 = v_1*ell_1/v_2
print("ell_2:", ell_2)
a = (ell_1+ell_2)/2
b = sqrt(ell_1*ell_2)
T = (2*pi*a*b)/(ell_1*v_1)
print("T:", T/(365*24*60*60))
e = (ell_2-ell_1)/(ell_2+ell_1)
print("e:", e)
# Out:
# v_2: 906.6806969191457
# ell_2: 5282214660876.463
# T: 76.08170065465508
# e: 0.9672889126454062

# %% [markdown]
# Exercise 2.7: Catalan numbers
# The Catalan numbers $C_n$ are a sequence of integers $1,1,2,5,14,42,132...$ that play an important role in quantum mechanics and the theory odf disordered systems. (They were central to Eugene Wigner's proof of the so-called semicircle law.) They are given by:
# $$C_0=1, C_{n+1}=\frac{4n + 2}{n + 2}C_n.$$
# Write a program that prints in increasing order all Catalan numbers less than equal to one billion.

# %%
#We define C_0 and C_n
C_n = 1
n=0
#We use a while loop to print C_n
while C_n <= 10**12:
    print(C_n)
    #We use the definition
    n += 1
    C_n = ((4*n+2)/(n+2))*C_n
# Out:
# 1
# 2.0
# 5.0
# 14.0
# 42.0
# 132.0
# 429.0
# 1430.0
# 4862.0
# 16796.0
# 58786.0
# 208012.0
# 742900.0
# 2674440.0
# 9694845.0
# 35357670.0
# 129644790.0
# 477638700.0
# 1767263190.0
# 6564120420.0
# 24466267020.0
# 91482563640.0
# 343059613650.0

# %% [markdown]
# Exercise 2.8: Suppose arrays $a$ and $b$ are defines as follows:
# a=array([1,2,3,4], int)
# b=array([2,4,6,8], int)
# What will the computer print upon executing the following lines?
# a) print(b/a+1)
# b) print(b/(a+1))
# c) print(1/a)

# %%
from numpy import array

a = array([1,2,3,4], int)
b = array([2,4,6,8], int)

print(b/a+1)
print(b/(a+1))
print(1/a)
# Out:
# [3. 3. 3. 3.]
# [1.         1.33333333 1.5        1.6       ]
# [1.         0.5        0.33333333 0.25      ]
